# %%
import sys
import numpy as np
import pandas as pd
import csv
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers import Conv2D, MaxPool2D, Flatten
from keras.optimizers import SGD,Adam
from keras.utils import np_utils
from keras.utils import to_categorical
from keras.layers.convolutional import Conv2D,MaxPooling2D

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
data=train.values

# %%
train_data=np.zeros((train.shape[0],48,48,1),dtype=int)
for i in range(train.shape[0]):
    image=train.iloc[i,1].split()
    image=list(map(float,image))
    image=np.array(image).reshape(-1,48,1)
    train_data[i]=image
train_labels=to_categorical(data[:,0])

# %%
plt.figure()
for i in range(10):
    im = train_data[i].reshape(48,48)
    plt.imshow(im,'gray')
    plt.pause(0.0000001)
plt.show()

# %%
train_data.shape
# Out:
# (28709, 48, 48, 1)

# %%
train_labels.shape
# Out:
# (28709, 7)

# %%
model = Sequential()  
model.add(Conv2D(24,(7,7),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))  
model.add(MaxPooling2D(pool_size=(3,3)))  
model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(MaxPooling2D(pool_size=(3,3)))  
model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(MaxPooling2D(pool_size=(1,1)))  
model.add(Flatten())  
model.add(Dense(1000,activation='relu'))  
model.add(Dropout(0.5))   
model.add(Dense(7,activation='softmax'))  
#model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(train_data,train_labels,batch_size=100,epochs=40)
result = model.evaluate(train_data,train_labels)
print ('\nTest Acc:', result[1])
# Out:
# Epoch 1/40
# 28709/28709 [==============================] - 4s 141us/step - loss: 1.7479 - acc: 0.3298
# Epoch 2/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 1.5293 - acc: 0.4120
# Epoch 3/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 1.4414 - acc: 0.4482
# Epoch 4/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 1.3806 - acc: 0.4725
# Epoch 5/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 1.3214 - acc: 0.4943
# Epoch 6/40
# 28709/28709 [==============================] - 3s 107us/step - loss: 1.2599 - acc: 0.5220
# Epoch 7/40
# 28709/28709 [==============================] - 3s 108us/step - loss: 1.2101 - acc: 0.5407
# Epoch 8/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 1.1646 - acc: 0.5627
# Epoch 9/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 1.1115 - acc: 0.5837
# Epoch 10/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 1.0317 - acc: 0.6106
# Epoch 11/40
# 28709/28709 [==============================] - 3s 108us/step - loss: 0.9659 - acc: 0.6352
# Epoch 12/40
# 28709/28709 [==============================] - 3s 111us/step - loss: 0.8861 - acc: 0.6679
# Epoch 13/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.8487 - acc: 0.6843
# Epoch 14/40
# 28709/28709 [==============================] - 3s 107us/step - loss: 0.7660 - acc: 0.7140
# Epoch 15/40
# 28709/28709 [==============================] - 3s 108us/step - loss: 0.6816 - acc: 0.7497
# Epoch 16/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 0.6509 - acc: 0.7602
# Epoch 17/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.5901 - acc: 0.7834
# Epoch 18/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.5624 - acc: 0.7953
# Epoch 19/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.5105 - acc: 0.8165
# Epoch 20/40
# 28709/28709 [==============================] - 3s 108us/step - loss: 0.4720 - acc: 0.8313
# Epoch 21/40
# 28709/28709 [==============================] - 3s 108us/step - loss: 0.4514 - acc: 0.8399
# Epoch 22/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 0.4246 - acc: 0.8491
# Epoch 23/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.4000 - acc: 0.8582
# Epoch 24/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.3932 - acc: 0.8614
# Epoch 25/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.3828 - acc: 0.8644
# Epoch 26/40
# 28709/28709 [==============================] - 3s 108us/step - loss: 0.3579 - acc: 0.8760
# Epoch 27/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.3408 - acc: 0.8829
# Epoch 28/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.3213 - acc: 0.8912
# Epoch 29/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 0.3345 - acc: 0.8835
# Epoch 30/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.3102 - acc: 0.8937
# Epoch 31/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.3198 - acc: 0.8904
# Epoch 32/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 0.3294 - acc: 0.8893
# Epoch 33/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.2681 - acc: 0.9088
# Epoch 34/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 0.3192 - acc: 0.8928
# Epoch 35/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.2930 - acc: 0.9032
# Epoch 36/40
# 28709/28709 [==============================] - 3s 108us/step - loss: 0.2733 - acc: 0.9098
# Epoch 37/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 0.2937 - acc: 0.9030
# Epoch 38/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.2895 - acc: 0.9050
# Epoch 39/40
# 28709/28709 [==============================] - 3s 109us/step - loss: 0.3178 - acc: 0.8977
# Epoch 40/40
# 28709/28709 [==============================] - 3s 110us/step - loss: 0.2821 - acc: 0.9089
# 28709/28709 [==============================] - 3s 107us/step
#
# Test Acc: 0.9741544463408687

# %%
test_data=np.zeros((test.shape[0],48,48,1),dtype=int)
for i in range(test.shape[0]):
    image=test.iloc[i,1].split()
    image=list(map(float,image))
    image=np.array(image).reshape(-1,48,1)
    test_data[i]=image

# %%
test_data.shape
# Out:
# (7178, 48, 48, 1)

# %%
test_label=model.predict(test_data)

# %%
test_label.shape
# Out:
# (7178, 7)

# %%
test_label[100]
# Out:
# array([1.2037281e-03, 9.0988870e-13, 1.5111422e-02, 1.2815965e-03,
#        5.1454321e-04, 5.8049352e-07, 9.8188812e-01], dtype=float32)

# %%
a=np.argmax(test_label, axis=1)

# %%
a.shape
# Out:
# (7178,)

# %%
f = open('y_test.csv',"w",newline='')
w = csv.writer(f)
title = ['id','label']
w.writerow(title) 
for i in range(0,7178):
    content = [str(i),a[i]]
    w.writerow(content) 
f.close()

# %%
for line in locals()['In']:
    print(line)
# Out:
# import sys
# import numpy as np
# import pandas as pd
# import csv
# import keras
# import tensorflow as tf
# import matplotlib.pyplot as plt
# from keras.models import Sequential
# from keras.layers.core import Dense, Dropout, Activation
# from keras.layers import Conv2D, MaxPool2D, Flatten
# from keras.optimizers import SGD,Adam
# from keras.utils import np_utils
# from keras.utils import to_categorical
# from keras.layers.convolutional import Conv2D,MaxPooling2D
# train=pd.read_csv('train.csv')
# test=pd.read_csv('test.csv')
# data=train.values
# train_data=np.zeros((train.shape[0],48,48,1),dtype=int)
# for i in range(train.shape[0]):
#     image=train.iloc[i,1].split()
#     image=list(map(float,image))
#     image=np.array(image).reshape(-1,48,1)
#     train_data[i]=image
# train_labels=to_categorical(data[:,0])
# train_data.shape
# train_labels.shape
# model = Sequential()
# model.add(Conv2D(48,(5,5),input_shape=(48,48,1),activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(25,(3,3),strides=(1,1),activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Flatten())
# model.add(Dense(100,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(50,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=20,epochs=20)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(96,(11,11),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(256,(5,5),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=20,epochs=20)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(96,(11,11),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(256,(5,5),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=20,epochs=20)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(96,(11,11),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(256,(5,5),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=20)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# test_data=np.zeros((test.shape[0],2304),dtype=int)
# for i in range(test.shape[0]):
#     image=test.iloc[i,1].split()
#     image=list(map(float,image))
#     image=np.array(image).reshape(-1,2304)
#     test_data[i]=image
# test_data=np.zeros((test.shape[0],48,48,1),dtype=int)
# for i in range(test.shape[0]):
#     image=test.iloc[i,1].split()
#     image=list(map(float,image))
#     image=np.array(image).reshape(-1,48,1)
#     test_data[i]=image
# test_data.shape
# test_label=model.predict(test_data)
# test_label[60]
# test_label[200]
# test_label[10]
# test_label[6]
# test_label[1]
# model = Sequential()
# model.add(Conv2D(96,(11,11),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(256,(5,5),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=100)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# test_label=model.predict(test_data)
# test_label[1]
# test_label[2]
# np.where(test_label[2]==np.max(test_label[2]))
# a=np.where(test_label[2]==np.max(test_label[2]))
# a
# a=np.where(test_label==np.max(test_label))
# a=np.where(test_label==np.max(test_label))
# a
# test_label.shape
# a=np.where(test_label==np.max(test_label),axis=1)
# a=np.where(test_label==np.max(test_label,axis=1))
# np.max(test_label,axis=1)
# b=np.max(test_label,axis=1)
# b
# b.shape
# test_label[0]
# test_label[2]
# b=np.max(test_label,axis=1)
# b.shape
# a=np.where(test_label==np.max(test_label,axis=1))
# b=np.max(test_label,axis=1)
# b[2]
# b[1]
# b[1]
# b[0]
# np.where(test_label== np.max(test_label,axis=1))
# np.where(test_label== np.max(test_label,axis=1))
# np.where(test_label== np.max(test_label,axis=0))
# np.where(test_label== np.max(test_label,axis=1))
# np.where(test_label== np.max(test_label,axis=1))
# np.where(test_label== np.max(test_label,axis=0))
# test_label.shape
# np.where(test_label== np.max(test_label,axis=0)).shape
# np.where(test_label== np.max(test_label,axis=0))
# b=np.where(test_label== np.max(test_label,axis=0))
# b.shape
# b=np.max(test_label,axis=1)
# b=np.where(test_label== b)
# b=np.where(test_label== np.max(test_label))
# b.shape
# b
# a=np.argmin(test_label, axis=1)
# a
# a.shape
# a[1]
# a[2]
# a[3]
# a[4]
# a[6]
# test_label[0]
# a[1]
# a[0]
# test_label[1]
# a=np.argmin(test_label, axis=1)
# a[2]
# a[3]
# a=np.argmax(test_label, axis=1)
# test_label.shape
# a[3]
# a[0]
# test_label[0]
# a[1]
# a[1]
# test_label[1]
# a[2]
# test_label[2]
# test_label[3]
# a[3]
# a.shape
# f = open('y_test1.csv',"w")
# w = csv.writer(f)
# title = ['id','label']
# w.writerow(title)
# for i in range(1,7178):
#     content = [str(i),a[i]]
#     w.writerow(content)
# f.close()
# f = open('y_test1.csv',"w",newline='')
# w = csv.writer(f)
# title = ['id','label']
# w.writerow(title)
# for i in range(1,7178):
#     content = [str(i),a[i]]
#     w.writerow(content)
# f.close()
# f = open('y_test.csv',"w",newline='')
# w = csv.writer(f)
# title = ['id','label']
# w.writerow(title)
# for i in range(1,7178):
#     content = [str(i),a[i]]
#     w.writerow(content)
# f.close()
# f = open('y_test.csv',"w",newline='')
# w = csv.writer(f)
# title = ['id','label']
# w.writerow(title)
# for i in range(1,7178):
#     content = [str(i),a[i]]
#     w.writerow(content)
# f.close()
# test_data.shape
# test_label=model.predict(test_data)
# test_label.shape
# test_label[3]
# test_label[3]
# test_label[500]
# model = Sequential()
# model.add(Conv2D(96,(11,11),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(256,(5,5),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=50)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(96,(11,11),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(256,(5,5),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=40)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# test_data.shape
# test_label=model.predict(test_data)
# test_label.shape
# test_label[500]
# test_label[500]
# a=np.argmax(test_label, axis=1)
# a.shape
# f = open('y_test.csv',"w",newline='')
# w = csv.writer(f)
# title = ['id','label']
# w.writerow(title)
# for i in range(1,7178):
#     content = [str(i),a[i]]
#     w.writerow(content)
# f.close()
# model = Sequential()
# model.add(Conv2D(24,(7,7),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1)))
# model.add(Flatten())
# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=40)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# test_label=model.predict(test_data)
# test_label.shape
# test_label[500]
# test_label[500]
# a=np.argmax(test_label, axis=1)
# a.shape
# test_label[1]
# test_label[0]
# test_label[1]
# test_label[2]
# test_label[3]
# test_label[4]
# model = Sequential()
# model.add(Conv2D(24,(7,7),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Flatten())
# model.add(Dense(512,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(128,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=40)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# test_label=model.predict(test_data)
# test_label.shape
# test_label[4]
# test_label[6]
# test_label[9]
# test_label[9]
# test_label[100]
# a=np.argmax(test_label, axis=1)
# a.shape
# f = open('y_test.csv',"w",newline='')
# w = csv.writer(f)
# title = ['id','label']
# w.writerow(title)
# for i in range(1,7178):
#     content = [str(i),a[i]]
#     w.writerow(content)
# f.close()
# a.shape
# a.shape
# f = open('y_test.csv',"w",newline='')
# w = csv.writer(f)
# title = ['id','label']
# w.writerow(title)
# for i in range(0,7177):
#     content = [str(i),a[i]]
#     w.writerow(content)
# f.close()
# f = open('y_test.csv',"w",newline='')
# w = csv.writer(f)
# title = ['id','label']
# w.writerow(title)
# for i in range(0,7178):
#     content = [str(i),a[i]]
#     w.writerow(content)
# f.close()
# model = Sequential()
# model.add(Conv2D(24,(7,7),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1)))
# model.add(Flatten())
# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=40)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(96,(11,11),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(256,(5,5),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=40)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(48,(7,7),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(64,(5,5),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1)))
# model.add(Flatten())
# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=40)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(96,(11,11),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(256,(5,5),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(384,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=100)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# test_data.shape
# test_label=model.predict(test_data)
# test_label.shape
# test_label[100]
# a=np.argmax(test_label, axis=1)
# a.shape
# f = open('y_test.csv',"w",newline='')
# w = csv.writer(f)
# title = ['id','label']
# w.writerow(title)
# for i in range(0,7178):
#     content = [str(i),a[i]]
#     w.writerow(content)
# f.close()
# model = Sequential()
# model.add(Conv2D(48,(5,5),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=100)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(48,(5,5),strides=(4,4),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=40)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(48,(5,5),input_shape=(48,48,1),padding='valid',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
# model.add(Conv2D(16,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(1,1),strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(500,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=40)
# result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(48,(5,5),input_shape=(48,48,1),activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(25,(3,3),strides=(1,1),activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Flatten())
# model.add(Dense(100,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(50,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=20,epochs=20)
# #result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# model = Sequential()
# model.add(Conv2D(48,(5,5),input_shape=(48,48,1),activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Conv2D(25,(3,3),strides=(1,1),activation='relu',kernel_initializer='uniform'))
# model.add(MaxPooling2D(pool_size=(3,3)))
# model.add(Flatten())
# model.add(Dense(100,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(50,activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7,activation='softmax'))
# #model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.fit(train_data,train_labels,batch_size=100,epochs=20)
# #result = model.evaluate(train_data,train_labels)
# print ('\nTest Acc:', result[1])
# for line in locals()['In']:
#     print(line)
